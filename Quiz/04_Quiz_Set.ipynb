# %% [markdown]
# ### **문제 6**
#
# 다음 조건에 맞게 **셋의 메서드**를 활용하세요.
#
# 1. `colors1`에 `'red', 'blue', 'green'`을 저장하세요.
# 2. `colors2`에 `'blue', 'yellow', 'pink'`를 저장하세요.
# 3. 두 셋의 **교집합**을 구하여 출력하세요.

# %%
colors1: set[str] = {'red', 'blue', 'green'}
colors2: set[str] = {'blue', 'yellow', 'pink'}

print(colors1, colors2)

print('두 셋의 교집합 : ' ,colors1.intersection(colors2))
# Out:
# {'green', 'blue', 'red'} {'blue', 'yellow', 'pink'}
# 두 셋의 교집합 :  {'blue'}

# %% [markdown]
# ### **문제 7**
#
# 다음 조건에 맞는 **딕셔너리 메서드**를 사용하세요.
#
# 1. `info` 딕셔너리에 `'name': 'Alice', 'age': 25, 'city': 'Seoul'`을 저장하세요.
# 2. `keys()` 메서드를 사용해 딕셔너리의 모든 키를 출력하세요.
# 3. `values()` 메서드를 사용해 딕셔너리의 모든 값을 출력하세요.

# %%
info: dict[str, str | int] = {'name': 'Alice', 'age': 25, 'city': 'Seoul'}
print(f'keys : {info.keys()}')
print(f'keys : {info.values()}')
# Out:
# keys : dict_keys(['name', 'age', 'city'])
# keys : dict_values(['Alice', 25, 'Seoul'])

# %% [markdown]
# ### **문제 9**
#
# 아래 조건에 맞는 **셋과 딕셔너리**를 사용하세요.
#
# 1. `numbers`라는 셋에 `{1, 2, 3, 4, 5}`를 저장하세요.
# 2. 딕셔너리 `squares`를 생성하고, 각 숫자를 키로, 숫자의 **제곱값**을 값으로 저장하세요.
# 3. 딕셔너리를 출력하세요.

# %%
numbers: set[int] = {1, 2, 3, 4, 5}
squares: dict[int, int] = {}

for number in numbers:
    squares[number] = number**2

print(f'square : {squares}')
for item in squares.items():
    print(f"squares item : {item}")
# Out:
# square : {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# squares item : (1, 1)
# squares item : (2, 4)
# squares item : (3, 9)
# squares item : (4, 16)
# squares item : (5, 25)

# %% [markdown]
# ### **문제 10**
#
# 다음 조건에 맞는 프로그램을 작성하세요.
#
# 1. 두 셋 `A = {1, 2, 3, 4}`와 `B = {3, 4, 5, 6}`가 있습니다.
# 2. `A`와 `B`의 **대칭 차집합**을 구하세요.
# 3. 결과를 `print()`를 사용해 출력하세요.

# %%
A: set[int] = {1,2,3}
B: set[int] = {3,4,5,6}

print("대칭 차집합 : ",B.symmetric_difference(A))
# Out:
# 대칭 차집합 :  {1, 2, 4, 5, 6}
